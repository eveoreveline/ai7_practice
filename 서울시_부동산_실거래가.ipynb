# %%
import pandas as pd
import seaborn as sns
import numpy as np
import matplotlib.pyplot as plt

pd.options.display.max_columns = None

# %%
df = pd.read_csv("서울시 부동산 실거래가 정보.csv", encoding='cp949')
df.head()
# Out:
# /var/folders/bc/60nf7pjs0rv35qdbssct76sc0000gn/T/ipykernel_41197/3307790369.py:1: DtypeWarning: Columns (7,19,20) have mixed types. Specify dtype option on import or set low_memory=False.
#   df = pd.read_csv("서울시 부동산 실거래가 정보.csv", encoding='cp949')
#    접수연도  자치구코드 자치구명  법정동코드 법정동명  지번구분 지번구분명     본번    부번           건물명  \
# 0  2022  11260  중랑구  10400   묵동   1.0    대지  389.0   0.0        태창네스트빌
# 1  2022  11530  구로구  10200  구로동   1.0    대지   97.0   0.0        로제리움2차
# 2  2022  11500  강서구  10300  화곡동   1.0    대지   94.0   1.0  블리스빌101동102동
# 3  2022  11620  관악구  10100  봉천동   1.0    대지   41.0  35.0        성지빌라7차
# 4  2022  11740  강동구  10900  천호동   1.0    대지  311.0   0.0          아메스빌
#
#         계약일  물건금액(만원)  건물면적(㎡)  토지면적(㎡)     층 권리구분  취소일    건축년도   건물용도  신고구분  \
# 0  20221121     51000    84.39     0.00   1.0  NaN  NaN  2005.0    아파트  중개거래
# 1  20221121     11300    14.04     0.00  18.0  NaN  NaN  2014.0    아파트   직거래
# ...

# %%
df = df[['접수연도','자치구명', '법정동명', '건물명', '계약일', '물건금액(만원)', '건물면적(㎡)', '토지면적(㎡)', '층', '건축년도', '건물용도', '신고구분']]
df.columns = ['접수연도','자치구명', '법정동명', '건물명', '계약일', '물건금액', '건물면적', '토지면적', '층', '건축년도', '건물용도', '신고구분']
df.head()
# Out:
#    접수연도 자치구명 법정동명           건물명       계약일   물건금액   건물면적   토지면적     층    건축년도  \
# 0  2022  중랑구   묵동        태창네스트빌  20221121  51000  84.39   0.00   1.0  2005.0
# 1  2022  구로구  구로동        로제리움2차  20221121  11300  14.04   0.00  18.0  2014.0
# 2  2022  강서구  화곡동  블리스빌101동102동  20221121  33000  29.99  21.17   3.0  2022.0
# 3  2022  관악구  봉천동        성지빌라7차  20221121  20300  53.45  25.29   4.0  1995.0
# 4  2022  강동구  천호동          아메스빌  20221121  27300  42.85  23.00   3.0  2010.0
#
#     건물용도  신고구분
# 0    아파트  중개거래
# 1    아파트   직거래
# 2  연립다세대   직거래
# 3  연립다세대  중개거래
# 4  연립다세대  중개거래

# %%
gwanak = df.loc[df['자치구명'] == '관악구']
gwanak.sort_values(by='물건금액', ascending=False)
# Out:
#         접수연도 자치구명 법정동명        건물명       계약일     물건금액     건물면적    토지면적    층  \
# 28751   2022  관악구  봉천동        NaN  20220328  1080000  1576.85  850.30  NaN
# 191558  2020  관악구  신림동        NaN  20201208   710000  2177.26  588.80  NaN
# 167923  2021  관악구  봉천동        NaN  20210125   700000   979.06  209.60  NaN
# 137513  2021  관악구  봉천동        NaN  20210409   688300   644.49  307.50  NaN
# 568690  2018  관악구  신림동        NaN  20180626   650000   589.76  485.00  NaN
# ...      ...  ...  ...        ...       ...      ...      ...     ...  ...
# 145882  2021  관악구  봉천동       백운빌라  20210319     4100    38.48   21.64 -1.0
# 607016  2018  관악구  신림동  (412-334)  20180317     4000    19.08   12.28  4.0
# 585547  2018  관악구  신림동      고원빌라트  20180510     4000    31.35   21.38 -1.0
# 58966   2021  관악구  신림동   (94-288)  20211102     3800    15.09    6.75 -1.0
# 440558  2019  관악구  신림동         경일  20190718     3400    30.25   16.17 -1.0
#
#           건축년도   건물용도  신고구분
# 28751   1985.0  단독다가구  중개거래
# ...
